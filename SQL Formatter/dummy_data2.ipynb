# %%
import json

with open('brand_details.json', 'r') as f:
    data = json.load(f)

# %%
import pandas as pd

# %%
import random

# %%
for i in l:
    print(f"INSERT INTO HyperMarket.brands(brand_id, brand_name)\n\tVALUES ('{i[0].replace(' ', '').upper()}', \"{i[1]}\");")
# Out:
# INSERT INTO HyperMarket.brands(brand_id, brand_name)
# 	VALUES ('KAV', "Le Kaviraj");
# INSERT INTO HyperMarket.brands(brand_id, brand_name)
# 	VALUES ('LLTE', "Milltec");
# INSERT INTO HyperMarket.brands(brand_id, brand_name)
# 	VALUES ('ASTI', "Swastik Steel");
# INSERT INTO HyperMarket.brands(brand_id, brand_name)
# 	VALUES ('LTI', "All Time");
# INSERT INTO HyperMarket.brands(brand_id, brand_name)
# 	VALUES ('MBOO', "Bamboooz");
# INSERT INTO HyperMarket.brands(brand_id, brand_name)
# 	VALUES ('EEN', "Green apple");
# INSERT INTO HyperMarket.brands(brand_id, brand_name)
# 	VALUES ('KVG', "Kvg");
# INSERT INTO HyperMarket.brands(brand_id, brand_name)
# 	VALUES ('TCHEN', "Kitchen Essentials");
# INSERT INTO HyperMarket.brands(brand_id, brand_name)
# 	VALUES ('APE', "Himalaya Pet Care");
# INSERT INTO HyperMarket.brands(brand_id, brand_name)
# 	VALUES ('REPE', "Purepet");
# INSERT INTO HyperMarket.brands(brand_id, brand_name)
# 	VALUES ('SWAS', "Swastik");
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/ashrulochan/Downloads/Final Products_data 1.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /home/ashrulochan/Downloads/sql-data/hypermarket/dummy_data2.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/ashrulochan/Downloads/sql-data/hypermarket/dummy_data2.ipynb#ch0000006?line=0'>1</a> df = pd.read_csv('/home/ashrulochan/Downloads/Final Products_data 1.csv')
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
