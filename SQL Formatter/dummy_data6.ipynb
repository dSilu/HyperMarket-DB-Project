# %% [markdown]
# #### Stocks data

# %%
import pandas as pd

# %%
df = pd.read_csv('stocks.csv')
df.head()
# Out:
#   outlet_id  product_id  quantity
# 0      ST01        2075        218
# 1      ST02        4652        131
# 2      ST01        1395        209
# 3      ST03         983        264
# 4      ST02        1021        249

# %%
df.duplicated().any()
# Out:
# False

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (4328, 3)

# %%
df.duplicated().any()
# Out:
# False

# %%
df.head()
# Out:
#   outlet_id  product_id  quantity
# 0      ST01        2075        218
# 1      ST02        4652        131
# 2      ST01        1395        209
# 3      ST03         983        264
# 4      ST02        1021        249

# %%
for row in df.iterrows():
    print(f"INSERT INTO HyperMarket.stocks(outlet_id, product_id, quantity)\n\tVALUES('{row[1][0]}', {row[1][1]}, {row[1][1]});")
# Out:
# INSERT INTO HyperMarket.stocks(outlet_id, product_id, quantity)
# 	VALUES('ST01', 2075, 2075);
# INSERT INTO HyperMarket.stocks(outlet_id, product_id, quantity)
# 	VALUES('ST02', 4652, 4652);
# INSERT INTO HyperMarket.stocks(outlet_id, product_id, quantity)
# 	VALUES('ST01', 1395, 1395);
# INSERT INTO HyperMarket.stocks(outlet_id, product_id, quantity)
# 	VALUES('ST03', 983, 983);
# INSERT INTO HyperMarket.stocks(outlet_id, product_id, quantity)
# 	VALUES('ST02', 1021, 1021);
# INSERT INTO HyperMarket.stocks(outlet_id, product_id, quantity)
# 	VALUES('ST04', 327, 327);
# INSERT INTO HyperMarket.stocks(outlet_id, product_id, quantity)
# 	VALUES('ST02', 2516, 2516);
# INSERT INTO HyperMarket.stocks(outlet_id, product_id, quantity)
# 	VALUES('ST01', 2298, 2298);
# INSERT INTO HyperMarket.stocks(outlet_id, product_id, quantity)
# 	VALUES('ST01', 1220, 1220);
# INSERT INTO HyperMarket.stocks(outlet_id, product_id, quantity)
# 	VALUES('ST02', 4410, 4410);
# ...
